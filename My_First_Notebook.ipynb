# %% [markdown]
# # This is a markdown cell. There are many markdown cells but this is my markdown cell.
#  '#FF0000' ## R
# ## O
# ## Y
# ## G
# ## B
# ## I
# ## V

# %%
print("Hello,World!")
# Out:
# Hello,World!
